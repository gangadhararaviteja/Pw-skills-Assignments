# %% [markdown]
# ## Question 1

# %% [raw]
# The wine quality dataset is a popular dataset used in machine learning and data analysis, consisting of information about the physicochemical properties of red and white wines, as well as their corresponding quality ratings. Some of the key features of this dataset include:
#
# 1. Fixed acidity: This feature represents the amount of non-volatile acids in the wine, which can impact its taste and pH level. Fixed acidity can be an important factor in predicting the quality of wine, as higher levels of acidity can result in a more tart and sour taste, which may be less desirable.
#
# 2. Volatile acidity: Unlike fixed acidity, volatile acidity refers to the amount of acids that can evaporate and contribute to a wine's aroma. However, high levels of volatile acidity can also indicate a wine that has started to spoil, resulting in an unpleasant taste and odor. As such, this feature can be useful in predicting the quality of wine.
#
# 3. Citric acid: This feature measures the amount of citric acid present in the wine, which can contribute to its overall flavor and freshness. Citric acid can also help to prevent oxidation and bacterial growth, which can negatively impact wine quality.
#
# 4. Residual sugar: This feature represents the amount of sugar that remains in the wine after fermentation. While some wines may have a higher level of residual sugar, this can also indicate a wine that has not fully fermented and may be less stable over time.
#
# 5. Chlorides: This feature measures the amount of salts and minerals present in the wine, which can impact its taste and mouthfeel. Higher levels of chlorides can result in a more salty or mineral-like taste, which may not be desirable for all wine drinkers.
#
# 6. Free sulfur dioxide: This feature measures the amount of sulfur dioxide present in the wine, which can act as a preservative and prevent bacterial growth. However, high levels of sulfur dioxide can also result in a wine that tastes and smells like sulfur, which may be less desirable.
#
# 7. Total sulfur dioxide: Similar to free sulfur dioxide, total sulfur dioxide measures the total amount of sulfur dioxide present in the wine. While this can be an important factor in predicting the quality of wine, it is important to consider the balance between the preservative properties of sulfur dioxide and its potential negative impact on taste and aroma.
#
# 8. Density: This feature measures the mass of the wine per unit volume, which can provide information about its alcohol and sugar content. However, density can also be influenced by other factors, such as temperature and pressure, which should be taken into account when predicting wine quality.
#
# 9. pH: This feature measures the acidity of the wine on a scale from 0 to 14. While a lower pH can result in a more tart and acidic taste, higher levels of acidity can also indicate a wine that has started to spoil or has not fully fermented.
#
# 10. Alcohol: This feature represents the percentage of alcohol in the wine, which can impact its taste, aroma, and body. Higher levels of alcohol can result in a wine that tastes stronger and fuller-bodied, but can also lead to a more intense and potentially unpleasant aftertaste.
#
# Overall, the key features of the wine quality dataset provide valuable information about the physicochemical properties of wine, which can be used to predict its overall quality and taste.

# %% [markdown]
# ## Question 2

# %% [raw]
# Wine quality dataset does not have any missing values.
# Missing data is a common issue in many datasets, including the wine quality dataset. When missing data is present, it can impact the quality and accuracy of any analysis or modeling performed on the data. In order to address this issue, there are several techniques that can be used to impute or fill in missing data. Some common imputation techniques include:
#
# Mean/median imputation: This technique involves replacing missing values with the mean or median value of the feature. The advantage of this technique is that it is simple to implement and can be effective when the missing values are randomly distributed. However, it can lead to biased estimates and does not take into account any correlations between features.
#
# Mode imputation: Mode imputation involves replacing missing values with the mode or most common value of the feature. This technique is useful for categorical features and is also simple to implement. However, it can also lead to biased estimates and does not take into account any correlations between features

# %% [markdown]
# ## Question 3

# %% [raw]
# the key factors that affect students' performance in exams are :
# - gender : sex of students  -> (Male/female)
# - race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
# - parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,high school)
# - lunch : having lunch before test (standard or free/reduced)
# - test preparation course : complete or not complete before test
# - math score
# - reading score
# - writing score

# %% [markdown]
# ## Question 4

# %% [raw]
# The process of feature engineering involves selecting and transforming variables in a dataset to create new features that are more informative or predictive of the target variable. In the context of the Student Performance dataset, the goal of feature engineering would be to identify variables that are most strongly associated with exam performance and to transform them in ways that improve the performance of a predictive model.
#
# The first step in the feature engineering process would be to perform exploratory data analysis to gain a better understanding of the relationships between the variables in the dataset and the target variable (i.e., exam scores). This might involve creating visualizations and running basic statistical analyses to identify correlations and patterns in the data.
#
# Next, we would need to select which variables to include in our model. Some variables in the dataset, such as "student ID" and "test preparation course," may not be informative predictors of exam performance and could be excluded. Other variables, such as "parental education" and "study time," may be strong predictors of exam performance and should be included in the model.
#
# Once the variables have been selected, we would need to transform them in ways that capture their relationships with the target variable. For example, we could transform the categorical variable "gender" into a binary variable (0 or 1) that represents male or female, respectively. We could also create new features by combining existing variables, such as creating a variable that represents the total education level of both parents.
#
# Other possible transformations might include normalizing or standardizing continuous variables, encoding categorical variables as dummy variables, or creating interaction terms between variables.
#
# Finally, we would need to evaluate the performance of our model using techniques such as cross-validation and comparing the accuracy of different models. This would allow us to determine which variables and transformations are most effective in predicting exam performance and to refine our feature engineering approach accordingly.
#
# Overall, the process of feature engineering in the context of the Student Performance dataset would involve selecting and transforming variables to create new features that are more informative predictors of exam performance

# %% [markdown]
# ## Question 5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.hist(figsize=(10,10))
plt.show()

# %% [raw]
# To improve normality in these features, we could apply various transformations:
#
# 1. Logarithmic transformation: This can be applied to features with right-skewed distributions, such as "residual sugar," "free sulfur dioxide," and "total sulfur dioxide."

# %%
df['residual sugar'] = np.log(df['residual sugar'])
df['free sulfur dioxide'] = np.log(df['free sulfur dioxide'])
df['total sulfur dioxide'] = np.log(df['total sulfur dioxide'])

# %% [raw]
# 2. Square root transformation: This can be applied to features with left-skewed distributions, such as "volatile acidity" and "chlorides."

# %%
df['volatile acidity'] = np.sqrt(df['volatile acidity'])
df['chlorides'] = np.sqrt(df['chlorides'])

# %% [raw]
# 3. Box-Cox transformation: This can be applied to features with highly skewed or multimodal distributions, such as "fixed acidity," "citric acid," and "alcohol."

# %%
from scipy.stats import boxcox

df['fixed acidity'] = boxcox(df['fixed acidity'])[0]
df['alcohol'] = boxcox(df['alcohol'])[0]

# %%
df.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# ## Question 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('winequality-red.csv')
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
pca = PCA()
pca.fit(scaled_data)
plt.plot(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_.cumsum(), marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.show()
pca = PCA(n_components=6)
pca_data = pca.fit_transform(scaled_data)
